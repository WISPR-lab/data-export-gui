# %%
from formats.json_ import JSONHandler

from formats.json_labelvalues import JSONLabelValuesHandler

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def test(path, handler):
    fstring = open(path, 'r').read()
    obj = handler.parse(fstring, path)
    return obj

# %%
# path = "/Users/julianonn/ipv-takeout/raw-data/bob_2_24_workingset/facebook/personal_information/profile_information/your_devices.json"
path = "/Users/julianonn/ipv-takeout/raw-data/bob_2_24_workingset/facebook/your_facebook_activity/other_activity/your_information_download_requests.json"


test(path, JSONLabelValuesHandler)
# Out:
# [{'Date range start': 1072944000,
#   'Date range end': 1737995696,
#   'Request completion time': 1738002357,
#   'How many times did you try to download the file?': 0,
#   'Information types': '',
#   'Media quality': 'Low',
#   'Output format': 'JSON',
#   'Have you seen this archive?': 'False',
#   'Have we notified you that your request is taking a long time to process?': 'False',
#   'Where you requested your data from': '',
#   'Files': '',
#   'timestamp': 1737995703},
#  {'Date range start': 1072944000,
#   'Date range end': 1737995696,
#   'Request completion time': 1739385562,
#   'How many times did you try to download the file?': 0,
#   'Information types': '',
#   'Media quality': 'Low',
#   'Output format': 'JSON',
#   'Have you seen this archive?': 'False',
#   'Have we notified you that your request is taking a long time to process?': 'False',
#   'Where you requested your data from': '',
#   'Files': '',
#   'timestamp': 1737995701},
# ...
